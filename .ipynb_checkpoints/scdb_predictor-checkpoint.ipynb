# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline
from fastai import *
from pathlib import Path
import numpy as np
import pandas as pd
bs =64
path = Path('/home/braunchauncey/data')
#scdb_df = pd.read_csv(path/'scdb/SCDB_2019_01_caseCentered_Citation.csv', encoding='iso-8859-1')
cl_df = pd.read_csv(path/'courtlistener/cl_scotus_opinions.csv')
#scotus_df = pd.concat([scdb_df,cl_df])
#scotus_df.info()
by_category = cl_df.groupby('category')
print(by_category.count().head())
print(by_category.size().tail())

by_judge = cl_df.groupby('judge')
print(by_judge.count().head())
print(by_judge.size().tail())
cl_df.info()
# Out:
#                                              id    url    uri  scdb_id  \
# category
# antitrust                                    62     62     62        8
# bankruptcy                                  184    184    184      121
# capital markets and corporate governance   2521   2521   2521     1239
# commercial                                   46     46     46       17
# corporate                                 14501  14501  14501     1642
#
#                                           jurisdiction  state   type  \
# category
# antitrust                                           62     62     62
# bankruptcy                                         184    184    184
# capital markets and corporate governance          2521   2521   2521
# commercial                                          46     46     46
# corporate                                        14501  14501  14501
#
#                                           resource_type   date  subcategory  \
# category
# ...
