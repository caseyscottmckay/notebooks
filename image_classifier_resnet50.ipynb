# %%
#javascript to get img urls (run in browser console after google img search for 'teddy bear'. Note: disable add blockers to get the csv file in separate window)
#urls=Array.from(document.querySelectorAll('.rg_i')).map(el=> el.hasAttribute('data-src')?el.getAttribute('data-src'):el.getAttribute('data-iurl'));
#window.open('data:text/csv;charset=utf-8,' + escape(urls.join('\n')));
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline
from fastai import *
from fastai.vision import *
from fastai.widgets import *
from google.colab import drive
drive.mount('/content/drive')

image_type='patents'
learn_pkl_name = image_type + '_image_classifer_resnet50_export.pkl'
path = Path('/content/drive/My Drive/data/' + image_type)

classes = os.listdir(path)
for c in classes:
  folder = c
  #file = 'urls_'+c+'.csv'
  dest = path/folder
  if not os._exists(dest):
    dest.mkdir(parents=True, exist_ok=True)
    #download_images(path/file, dest, max_pics=10)
for c in classes: 
  print(c)
  verify_images(path/c, delete=True, max_workers=8)
np.random.seed(42)
data = ImageDataBunch.from_folder(path, train=".", valid_pct=0.2,
        ds_tfms=get_transforms(), size=224, num_workers=4).normalize(imagenet_stats)
data.classes
data.show_batch(rows=3, figsize=(7,8))
data.classes, data.c, len(data.train_ds), len(data.valid_ds)
#Train
learn = cnn_learner(data, models.resnet50, metrics=error_rate)
learn.lr_find()
learn.recorder.plot()
learn.fit_one_cycle(1) #todo original 8
learn.save('stage-1-50')
learn.unfreeze()
learn.fit_one_cycle(1, max_lr=slice(1e-6, 1e-4)) #todo epochs should be 3
learn.load('stage-1-50');
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_confusion_matrix()
learn.export(path/learn_pkl_name)
#defaults.device = torch.device('cpu')
#img = open_image(path/'advertising'/'1.BANGADSMEDIA_51.jpg')
#img
learn = load_learner(path, learn_pkl_name)
pred_class,pred_idx,outputs=learn.predict(img)
pred_class
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# abrading
# dynamic_magnetic_information_storage_or_retrieval
# pipes_and_tubular_conduits
# imperforate_bowl_centrifugal_separators
# interactive_video_distribution_systems
# hazardous_or_toxic_waste_destruction_or_containment
# railway_mail_delivery
# receptacles
# unearthing_plants_or_buried_objects
# coded_data_generation_or_conversion
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:1044: UserWarning: Couldn't allocate palette entry for transparency
#   warnings.warn("Couldn't allocate palette entry for transparency")
# miscellaneous
# nuclear_technology
# sheet-material_associating
# trunks_and_hand-carried_luggage
# inductor_devices
# planetary_gear_transmission_systems_or_components
# electric_lamp_and_discharge_devices_systems
# electronic_digital_logic_circuitry
# electrical_computers_and_digital_processing_systems_virtual_machine_task_or_process_management_or_task_managementcontrol
# wheelwright_machines
# automatic_temperature_and_humidity_regulation
# electric_resistance_heating_devices
# office_supplies_artists_and_teachers_materials
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:1044: UserWarning: Couldn't allocate palette entry for transparency
#   warnings.warn("Couldn't allocate palette entry for transparency")
# travel_goods_and_personal_belongings
# chemistry_of_carbon_compounds
# multiplex_communications
# wooden_receptacles
# catalyst_solid_sorbent_or_support_therefor_product_or_process_of_making
# nanotechnology
# distillation_apparatus
# friction_gear_transmission_systems_or_components
# tools_and_hardware
# motors_expansible_chamber_type
# tool_driving_or_impacting
# cryptography
# roll_or_roller
# fabric_woven_knitted_or_nonwoven_textile_or_cloth_etc
# gas_and_liquid_contact_apparatus
# incremental_printing_of_symbolic_information
# chemical_apparatus_and_process_disinfecting_deodorizing_preserving_or_sterilizing
# surgery_splint_brace_or_bandage
# data_processing_structural_design_modeling_simulation_and_emulation
# fluid_reaction_surfaces_ie_impellers
# purses_wallets_and_protective_covers
# liquid_purification_or_separation
# textiles_braiding_netting_and_lace_making
# building_units_and_construction_elements
# 192_clutches_and_power-stop_control
# washing_cleaning_or_drying_machine
# sheet_metal_container_making
# miscellaneous_active_electrical_nonlinear_devices_circuits_and_systems
# supports
# power_plants
# electrical_computers_and_digital_processing_systems_memory
# textiles_ironing_or_smoothing
# metal_treatment
# chemistry_fischer-tropsch_processes_or_purification_or_recovery_of_products_thereof
# horology
# packages_and_containers_for_goods
# demodulators
# tools
# amusement_devices_toys
# heat_exchange
# measuring_and_testing
# cleaning_and_liquid_contact_with_solids
# mechanical_guns_and_projectors
# metal_founding
# textiles_knitting
# baths_closets_sinks_and_spittoons
# dispensing
# amusement_devices_games
# recording_communication_or_information_retrieval_equipment
# safes_bank_protection_or_a_related_device
# textiles_manufacturing
# plastic_article_or_earthenware_shaping_or_treating_apparatus
# resilient_tires_and_wheels
# amusement_devices
# communications_electrical
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:1044: UserWarning: Couldn't allocate palette entry for transparency
#   warnings.warn("Couldn't allocate palette entry for transparency")
# check-actuated_control_mechanisms
# metal_fusion_bonding
# fishing_trapping_and_vermin_destroying
# gear_cutting_milling_or_planing
# metal_working
# classifying_separating_and_assorting_solids
# ammunition_and_explosives
# electrical_resistors
# registers
# textiles_weaving
# material_or_article_handling
# electrical_computers_and_digital_processing_systems_interprogram_communication_or_interprocess_communication_ipc
# furnaces
# hydraulic_and_earth_engineering
# electricity_electrical_systems_and_devices
# dentistry
# chain_staple_and_horseshoe_making
# seal_for_a_joint_or_juncture
# data_processing_generic_control_systems_or_specific_applications
# tobacco_and_smokers_supplies
# land_vehicles_bodies_and_tops
# boots_shoes_and_leggings
# electricity_motive_power_systems
# ordnance
# lubrication
# distillation_processes_thermolytic
# textiles_cloth_finishing
# furnishings
# chemistry_electrical_and_wave_energy
# equipment_for_safety_protection_and_rescue
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:1044: UserWarning: Couldn't allocate palette entry for transparency
#   warnings.warn("Couldn't allocate palette entry for transparency")
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:1044: UserWarning: Couldn't allocate palette entry for transparency
#   warnings.warn("Couldn't allocate palette entry for transparency")
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:1044: UserWarning: Couldn't allocate palette entry for transparency
#   warnings.warn("Couldn't allocate palette entry for transparency")
# joints_and_connections
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:1044: UserWarning: Couldn't allocate palette entry for transparency
#   warnings.warn("Couldn't allocate palette entry for transparency")
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:1044: UserWarning: Couldn't allocate palette entry for transparency
#   warnings.warn("Couldn't allocate palette entry for transparency")
# data_processing_measuring_calibrating_or_testing
# liquid_heaters_and_vaporizers
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:989: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# high-voltage_switches_with_arc_preventing_or_extinguishing_devices
# electrical_pulse_counters_pulse_dividers_or_shift_registers_circuits_and_systems
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:1044: UserWarning: Couldn't allocate palette entry for transparency
#   warnings.warn("Couldn't allocate palette entry for transparency")
# wave_transmission_lines_and_networks
# brakes
# data_processing_software_development_installation_and_management
# handling_hand_and_hoist-line_implements
# electrolysis_processes_compositions_used_therein_and_methods_of_preparing_the_compositions
# machine_element_or_mechanism
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:1044: UserWarning: Couldn't allocate palette entry for transparency
#   warnings.warn("Couldn't allocate palette entry for transparency")
# data_processing_database_and_file_management_or_data_structures
# cutters_for_shaping
# fluid_sprinkling_spraying_and_diffusing
# endless_belt_power_transmission_systems_or_components
# road_structure_process_or_apparatus
# textiles_fiber_preparation
# recorders
# synthetic_resins_or_natural_rubbers
# combinatorial_chemistry_technology_method_library_apparatus
# deposit_and_collection_receptacles
# pipe_joints_or_couplings
# electricity_transmission_to_vehicles
# whips_and_whip_apparatus
# bearings
# cutting
# needle_and_pin_making
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:989: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# electric_lamp_or_space_discharge_component_or_device_manufacturing
# radiation_imagery_chemistry_process_composition_or_product_thereof
# computer_graphics_processing_and_selective_visual_display_systems
# rotary_kinetic_fluid_motors_or_pumps
# education_and_demonstration
# closure_fasteners
# spring_devices
# electrical_computers_arithmetic_processing_and_calculating
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:1044: UserWarning: Couldn't allocate palette entry for transparency
#   warnings.warn("Couldn't allocate palette entry for transparency")
# work_holders
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:1044: UserWarning: Couldn't allocate palette entry for transparency
#   warnings.warn("Couldn't allocate palette entry for transparency")
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:1044: UserWarning: Couldn't allocate palette entry for transparency
#   warnings.warn("Couldn't allocate palette entry for transparency")
# robots
# radiant_energy
# buckles_buttons_clasps_etc
# electrophotography
# type_casting
# industrial_electric_heating_furnaces
# perfume_compositions
# distillation_processes_separatory
# tuners
# chemistry_natural_resins_or_derivatives_peptides_or_proteins_lignins_or_reaction_products_thereof
# dynamic_information_storage_or_retrieval
# medical_and_laboratory_equipment
# organic_compounds_containing_a_bi_sb_as_or_p_atom_or_containing_a_metal_atom_of_the_6th_to_8th_group_of_the_periodic_system
# chemistry_physical_processes
# optics_measuring_and_testing
# advancing_material_of_indeterminate_length
# paper_making_and_fiber_liberation
# static_molds
# foundation_garments
# planting
# supports_cabinet_structure
# supports_racks
# abrasive_tool_making_process_material_or_composition
# special_receptacle_or_package
# powder_metallurgy_processes
# bridges
# electric_lamp_and_discharge_devices_consumable_electrodes
# food_or_edible_material_processes_compositions_and_products
# interrelated_power_delivery_controls_including_engine_control
# sales_and_advertising_equipment
# land_vehicles_animal_draft_appliances
# musical_instruments
# alloys_or_metallic_compositions
# electrical_computers_and_digital_processing_systems_multicomputer_data_transferring
# multicellular_living_organisms_and_unmodified_parts_thereof_and_related_processes
# modulators
# electricity_magnetically_operated_switches_magnets_and_electromagnets
# typesetting
# vehicle_fenders
# heating_systems
# organic_compounds
# printed_matter
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:1044: UserWarning: Couldn't allocate palette entry for transparency
#   warnings.warn("Couldn't allocate palette entry for transparency")
# bleaching_and_dyeing_fluid_treatment_and_chemical_modification_of_textiles_and_fibers
# surgery_light_thermal_and_electrical_application
# hybrid_electric_vehicles_hevs
# oscillators
# tent_canopy_umbrella_or_cane
# coherent_light_generators
# chemistry_of_hydrocarbon_compounds
# rotary_shafts_gudgeons_housings_and_flexible_couplings_for_rotary_shafts
# earth_boring_well_treating_and_oil_field_chemistry
# flexible_bags
# metallurgical_apparatus
# exercise_devices
# television
# sheet_feeding_or_delivering
# manufacturing_container_or_tube_from_paper_or_other_manufacturing_from_a_sheet_or_web
# tobacco
# information_security
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:1044: UserWarning: Couldn't allocate palette entry for transparency
#   warnings.warn("Couldn't allocate palette entry for transparency")
# static_information_storage_and_retrieval
# textile_or_paper_yard_goods_sheet_material
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:1044: UserWarning: Couldn't allocate palette entry for transparency
#   warnings.warn("Couldn't allocate palette entry for transparency")
# semiconductor_device_manufacturing_process
# equipment_for_production_distribution_or_transformation_of_energy
# communications_electrical_acoustic_wave_systems_and_devices
# pulse_or_digital_communications
# flexible_or_portable_closure_partition_or_panel
# games_toys_and_sports_goods
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:1044: UserWarning: Couldn't allocate palette entry for transparency
#   warnings.warn("Couldn't allocate palette entry for transparency")
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:1044: UserWarning: Couldn't allocate palette entry for transparency
#   warnings.warn("Couldn't allocate palette entry for transparency")
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:1044: UserWarning: Couldn't allocate palette entry for transparency
#   warnings.warn("Couldn't allocate palette entry for transparency")
# drying_and_gas_or_vapor_contact_with_solids
# wireworking
# railway_rolling_stock
# electrical_audio_signal_processing_systems_and_devices
# solid_anti-friction_devices_materials_therefor_lubricant_or_separant_compositions_for_moving_solid_surfaces_and_miscellaneous_mineral_oil_compositions
# prosthesis_ie_artificial_body_members_parts_thereof_or_aids_and_accessories_therefor
# environmental_heating_and_cooling_fluid_handling_and_sanitary_equipment
# bookbinding_process_and_apparatus
# apparel_and_haberdashery
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:1044: UserWarning: Couldn't allocate palette entry for transparency
#   warnings.warn("Couldn't allocate palette entry for transparency")
# boring_or_penetrating_the_earth
# chairs_and_seats
# wells
# coopering
# equipment_for_preparing_or_serving_food_or_drink_not_elsewhere_specified
# wood_turning
# butchering
# single-crystal_oriented-crystal_and_epitaxy_growth_processes_non-coating_apparatus_therefor
# dynamic_optical_information_storage_or_retrieval
# gas_separation
# electronic_funds_transfer
# freight_accommodation_on_freight_carrier
# explosive_and_thermic_compositions_or_charges
# thermal_measuring_and_testing
# miscellaneous_hardware_eg_bushing_carpet_fastener_caster_door_closer_panel_hanger_attachable_or_adjunct_handle_hinge_window_sash_balance_etc
# mineral_oils_processes_and_products
# aeronautics_and_astronautics
# electrical_computers_and_digital_processing_systems_processing_architectures_and_instruction_processing_eg_processors
# motion_video_signal_processing_for_recording_or_reproducing
# conveyors_chutes_skids_guides_and_ways
# compositions
# woodworking
# motor_vehicles
# buoys_rafts_and_aquatic_devices
# books_strips_and_leaves_for_manifolding
# photography_and_optical_equipment
# undertaking
# x-ray_or_gamma_ray_systems_or_devices
# crop_threshing_or_separating
# refrigeration
# illumination
# internal-combustion_engines
# facsimile_and_static_presentation_processing
# package_and_article_carriers
# brushing_scrubbing_and_general_cleaning
# prime-mover_dynamo_plants
# chemistry_electrical_current_producing_apparatus_product_and_process
# electric_heating
# knots_and_knot_tying
# drug_bio-affecting_and_body_treating_compositions
# wheel_substitutes_for_land_vehicles
# stock_material_or_miscellaneous_articles
# beds
# ventilation
# transportation
# ships
# heating
# bee_culture
# electricity_conductors_and_insulators
# arms_pyrotechnics_hunting_and_fishing_equipment
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:1044: UserWarning: Couldn't allocate palette entry for transparency
#   warnings.warn("Couldn't allocate palette entry for transparency")
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:1044: UserWarning: Couldn't allocate palette entry for transparency
#   warnings.warn("Couldn't allocate palette entry for transparency")
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:1044: UserWarning: Couldn't allocate palette entry for transparency
#   warnings.warn("Couldn't allocate palette entry for transparency")
# electricity_measuring_and_testing
# sugar_starch_and_carbohydrates
# cosmetic_products_and_toilet_articles
# fluid-pressure_and_analogous_brake_systems
# binder_device_releasably_engaging_aperture_or_notch_of_sheet
# coin_handling
# agitating
# valves_and_valve_actuation
# electricity_motor_control_systems
# electrical_transmission_or_interconnection_systems
# turning
# optics_motion_pictures
# metal_deforming
# track_sanders
# colloid_systems_and_wetting_agents_subcombinations_thereof_processes_of
# cutting_by_use_of_rotating_axially_moving_tool
# brush_broom_and_mop_making
# chemistry_molecular_biology_and_microbiology
# computer-aided_design_and_analysis_of_circuits_and_semiconductor_masks
# telephonic_communications
# printing_and_office_machinery
# metal_tools_and_implements_making
# acoustics
# severing_by_tearing_or_breaking
# land_vehicles_wheels_and_axles
# music
# fire_extinguishers
# image_analysis
# railway_switches_and_signals
# jewelry_symbolic_insignia_and_ornaments
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:1044: UserWarning: Couldn't allocate palette entry for transparency
#   warnings.warn("Couldn't allocate palette entry for transparency")
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:1044: UserWarning: Couldn't allocate palette entry for transparency
#   warnings.warn("Couldn't allocate palette entry for transparency")
# data_processing_vehicles_navigation_and_relative_location
# electricity_battery_or_capacitor_charging_or_discharging
# combustion
# weighing_scales
# electricity_power_supply_or_regulation_systems
# telecommunications
# electrical_computers_and_digital_data_processing_systems_inputoutput
# article_dispensing
# textiles_spinning_twisting_and_twining
# bottles_and_jars
# railways_surface_track
# package_making
# etching_a_substrate_processes
# coating_processes
# data_processing_financial_business_practice_management_or_costprice_determination
# cutlery
# fluent_material_handling_with_receiver_or_receiver_coacting_means
# stoves_and_furnaces
# elongated-member-driving_apparatus
# wire_fabrics_and_structure
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:1044: UserWarning: Couldn't allocate palette entry for transparency
#   warnings.warn("Couldn't allocate palette entry for transparency")
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:1044: UserWarning: Couldn't allocate palette entry for transparency
#   warnings.warn("Couldn't allocate palette entry for transparency")
# communications_radio_wave_antennas
# edible_products
# cleaning_compositions_for_solid_surfaces_auxiliary_compositions_therefor_or_processes_of_preparing_the_compositions
# lighting
# leather_manufactures
# animal_husbandry
# compound_tools
# data_processing_artificial_intelligence
# envelopes_wrappers_and_paperboard_boxes
# plants
# induced_nuclear_reactions_processes_systems_and_elements
# optical_waveguides
# railways
# elevator_industrial_lift_truck_or_stationary_lift_for_vehicle
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:989: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# button_making
# data_processing_speech_signal_processing_linguistics_language_translation_and_audio_compressiondecompression
# farriery
# chemistry_fertilizers
# railway_draft_appliances
# railway_wheels_and_axles
# compositions_coating_or_plastic
# traversing_hoists
# electrical_computers_and_digital_processing_systems_support
# plant_protecting_and_regulating_compositions
# expansible_chamber_devices
# presses
# communications_directive_radio_wave_systems_and_devices_eg_radar_radio_navigation
# fire_escape_ladder_or_scaffold
# machines_not_elsewhere_specified
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:989: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:1044: UserWarning: Couldn't allocate palette entry for transparency
#   warnings.warn("Couldn't allocate palette entry for transparency")
# telegraphy
# chucks_or_sockets
# optical_systems_and_elements
# conveyors_fluid_current
# motors_spring_weight_or_animal_powered
# games_using_tangible_projectile
# glass_manufacturing
# electrical_connectors
# electricity_single_generator_systems
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:1044: UserWarning: Couldn't allocate palette entry for transparency
#   warnings.warn("Couldn't allocate palette entry for transparency")
# earth_working
# active_solid-state_devices_eg_transistors_solid-state_diodes
# chemistry_analytical_and_immunological_testing
# jewelry
# locks
# coating_implements_with_material_supply
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:1044: UserWarning: Couldn't allocate palette entry for transparency
#   warnings.warn("Couldn't allocate palette entry for transparency")
# rotary_expansible_chamber_devices
# movable_or_removable_closures
# liquid_crystal_cells_elements_and_systems
# signals_and_indicators
# static_structures_eg_buildings
# brushware
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:1044: UserWarning: Couldn't allocate palette entry for transparency
#   warnings.warn("Couldn't allocate palette entry for transparency")
# merchandising
# ammunition_and_explosive-charge_making
# specialized_metallurgical_processes_compositions_for_use_therein_consolidated_metal_powder_compositions_and_loose_metal_particulate_mixtures
# electricity_electrothermally_or_thermally_actuated_switches
# typewriting_machines
# scanning-probe_techniques_or_apparatus_applications_of_scanning-probe_techniques_eg_scanning_probe_microscopy_spm
# harvesters
# harness_for_working_animal
# surgery
# mineral_oils_apparatus
# electric_lamp_and_discharge_devices
# fences
# electricity_circuit_makers_and_breakers
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:1044: UserWarning: Couldn't allocate palette entry for transparency
#   warnings.warn("Couldn't allocate palette entry for transparency")
# textiles_fluid_treating_apparatus
# printing
# surgery_kinesitherapy
# apparel
# winding_tensioning_or_guiding
# apparel_apparatus
# plant_husbandry
# sewing
# geometrical_instruments
# expanded_threaded_driven_headed_tool-deformed_or_locked-threaded_fastener
# tool_changing
# coating_apparatus
# land_vehicles
# batteries_thermoelectric_and_photoelectric
# implements_or_apparatus_for_applying_pushing_or_pulling_force
# firearms
# land_vehicles_dumping
# toilet
# photocopying
# chemistry_of_inorganic_compounds
# conveyors_power-driven
# error_detectioncorrection_and_fault_detectionrecovery
# data_processing_presentation_processing_of_document_operator_interface_processing_and_screen_saver_display_processing
# photography
# amplifiers
# gas_separation_processes
# threaded_headed_fastener_or_washer_making_process_and_apparatus
# fluid_handling
# optics_image_projectors
# pumps
# optical_communications
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:1044: UserWarning: Couldn't allocate palette entry for transparency
#   warnings.warn("Couldn't allocate palette entry for transparency")
# gas_heating_and_illuminating
# concentrating_evaporators
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:1044: UserWarning: Couldn't allocate palette entry for transparency
#   warnings.warn("Couldn't allocate palette entry for transparency")
# electrical_generator_or_motor_structure
# card_picture_or_sign_exhibiting
# electric_power_conversion_systems
# horology_time_measuring_systems_or_devices
# selective_cutting_eg_punching
# solid_material_comminution_or_disintegration
# marine_propulsion
# peptide_or_protein_sequence
# foods_and_beverages_apparatus
# fuel_and_related_compositions
# boot_and_shoe_making
# plastic_and_nonmetallic_article_shaping_or_treating_processes
# gas_separation_apparatus
# optics_eye_examining_vision_testing_and_correcting
# superconductor_technology_apparatus_material_process
# stone_working
# record_receiver_having_plural_interactive_leaves_or_a_colorless_color_former_method_of_use_or_developer_therefor
# adhesive_bonding_and_miscellaneous_chemical_manufacture
# material_or_article_handling_equipment
# books_strips_and_leaves
# mining_or_in_situ_disintegration_of_hard_material
# excavating
# horizontally_supported_planar_surfaces
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:1044: UserWarning: Couldn't allocate palette entry for transparency
#   warnings.warn("Couldn't allocate palette entry for transparency")
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:1044: UserWarning: Couldn't allocate palette entry for transparency
#   warnings.warn("Couldn't allocate palette entry for transparency")
# measuring_testing_or_signalling_instruments
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:1044: UserWarning: Couldn't allocate palette entry for transparency
#   warnings.warn("Couldn't allocate palette entry for transparency")
# compositions_ceramic
# /usr/local/lib/python3.6/dist-packages/fastai/vision/data.py:306: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
#   plt.tight_layout()
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='3' class='' max='4', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       75.00% [3/4 02:07<00:42]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>8.115183</td>
#       <td>#na#</td>
#       <td>00:42</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>8.023486</td>
#       <td>#na#</td>
#       <td>00:42</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>7.928308</td>
#       <td>#na#</td>
#       <td>00:42</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='10' class='' max='27', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       37.04% [10/27 00:19<00:32 25.9672]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>7.411103</td>
#       <td>6.228261</td>
#       <td>0.981777</td>
#       <td>00:52</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>5.597600</td>
#       <td>6.121392</td>
#       <td>0.984055</td>
#       <td>00:52</td>
#     </tr>
#   </tbody>
# </table>
# /usr/local/lib/python3.6/dist-packages/fastai/train.py:213: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()
# Category registers

# %%
#img = open_image(path/'carpets'/'1.fd7b9276073ab01dde5a6ed97e1ba95e.jpg')
#img = open_image(path/'compositions_ceramic'/'5.bottle-support-patent-drawing-from-1937-mugs.jpg')
#img
learn = load_learner(path,learn_pkl_name)
pred_class,pred_idx,outputs=learn.predict(img)
pred_class
# Out:
# Category land_vehicles
